# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
import json

#import the api key
from CenKey import CensusKey

# %%
#https://api.census.gov/data/2021/pep/population?get=PPOPCHG_CUM2021,NAME,STATE&for=state:*&key={0}
url = "https://api.census.gov/data/2021/pep/population?get=PPOPCHG_CUM2021,NAME,STATE&for=state:*&key={0}".format(CensusKey)
response = requests.request("GET",url)
Data = json.loads(response.text)
PercentChange = pd.DataFrame(Data)
PercentChange.to_csv('Percentage change.csv')
PercentChange
# Out:
#                   0                     1      2      3
# 0   PPOPCHG_CUM2021                  NAME  STATE  state
# 1      0.6891530005              Oklahoma     40     40
# 2      0.1115470578              Nebraska     31     31
# 3     -0.9426422980                Hawaii     15     15
# 4      0.9822176759          South Dakota     46     46
# 5      0.9315510126             Tennessee     47     47
# 6      1.2683380285                Nevada     32     32
# 7     -0.0776851430            New Mexico     35     35
# 8      0.0849431523                  Iowa     19     19
# 9     -0.1122578190                Kansas     20     20
# 10    -2.8272266490  District of Columbia     11     11
# 11     1.3121611720                 Texas     48     48
# 12     0.2156651118              Missouri     29     29
# 13     0.4770674250              Arkansas     05     05
# 14    -0.2631649190              Michigan     26     26
# 15     0.8321421908         New Hampshire     33     33
# ...

# %%
url = "https://api.census.gov/data/2021/pep/population?get=NAME,POP_2021&RACE=0&for=state:*&key={0}".format(CensusKey)
response = requests.request("GET",url)
Data = json.loads(response.text)
DemographicChange = pd.DataFrame(Data)
DemographicChange
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\Comma\Downloads\Project 3 my bit\LoadApi.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Comma/Downloads/Project%203%20my%20bit/LoadApi.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> url = "https://api.census.gov/data/2021/pep/population?get=NAME,POP_2021&RACE=0&for=state:*&key={0}".format(CensusKey)
#       <a href='vscode-notebook-cell:/c%3A/Users/Comma/Downloads/Project%203%20my%20bit/LoadApi.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> response = requests.request("GET",url)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Comma/Downloads/Project%203%20my%20bit/LoadApi.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> Data = json.loads(response.text)
#       <a href='vscode-notebook-cell:/c%3A/Users/Comma/Downloads/Project%203%20my%20bit/LoadApi.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> DemographicChange = pd.DataFrame(Data)
# ...
